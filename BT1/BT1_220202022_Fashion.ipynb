# %%
# install require package
# !pip install pandas numpy matplotlib scikit-learn torch torchvision tqdm
# Out:
# Requirement already satisfied: pandas in ./lib/python3.10/site-packages (2.2.2)
# Requirement already satisfied: numpy in ./lib/python3.10/site-packages (1.26.4)
# Requirement already satisfied: matplotlib in ./lib/python3.10/site-packages (3.8.4)
# Requirement already satisfied: scikit-learn in ./lib/python3.10/site-packages (1.4.2)
# Requirement already satisfied: torch in ./lib/python3.10/site-packages (2.3.0)
# Requirement already satisfied: torchvision in ./lib/python3.10/site-packages (0.18.0)
# Requirement already satisfied: tqdm in ./lib/python3.10/site-packages (4.66.4)
# Requirement already satisfied: tzdata>=2022.7 in ./lib/python3.10/site-packages (from pandas) (2024.1)
# Requirement already satisfied: pytz>=2020.1 in ./lib/python3.10/site-packages (from pandas) (2024.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./lib/python3.10/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: fonttools>=4.22.0 in ./lib/python3.10/site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: cycler>=0.10 in ./lib/python3.10/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: pyparsing>=2.3.1 in ./lib/python3.10/site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: contourpy>=1.0.1 in ./lib/python3.10/site-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./lib/python3.10/site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: pillow>=8 in ./lib/python3.10/site-packages (from matplotlib) (10.3.0)
# Requirement already satisfied: packaging>=20.0 in ./lib/python3.10/site-packages (from matplotlib) (24.0)
# Requirement already satisfied: joblib>=1.2.0 in ./lib/python3.10/site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in ./lib/python3.10/site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: scipy>=1.6.0 in ./lib/python3.10/site-packages (from scikit-learn) (1.13.0)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in ./lib/python3.10/site-packages (from torch) (10.3.2.106)
# Requirement already satisfied: networkx in ./lib/python3.10/site-packages (from torch) (3.3)
# Requirement already satisfied: sympy in ./lib/python3.10/site-packages (from torch) (1.12)
# Requirement already satisfied: filelock in ./lib/python3.10/site-packages (from torch) (3.14.0)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in ./lib/python3.10/site-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in ./lib/python3.10/site-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in ./lib/python3.10/site-packages (from torch) (8.9.2.26)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in ./lib/python3.10/site-packages (from torch) (11.4.5.107)
# Requirement already satisfied: typing-extensions>=4.8.0 in ./lib/python3.10/site-packages (from torch) (4.11.0)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in ./lib/python3.10/site-packages (from torch) (12.1.0.106)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in ./lib/python3.10/site-packages (from torch) (12.1.105)
# Requirement already satisfied: fsspec in ./lib/python3.10/site-packages (from torch) (2024.3.1)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in ./lib/python3.10/site-packages (from torch) (12.1.3.1)
# Requirement already satisfied: jinja2 in ./lib/python3.10/site-packages (from torch) (3.1.4)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in ./lib/python3.10/site-packages (from torch) (11.0.2.54)
# Requirement already satisfied: triton==2.3.0 in ./lib/python3.10/site-packages (from torch) (2.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in ./lib/python3.10/site-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in ./lib/python3.10/site-packages (from torch) (2.20.5)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in ./lib/python3.10/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch) (12.4.127)
# Requirement already satisfied: six>=1.5 in ./lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in ./lib/python3.10/site-packages (from jinja2->torch) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in ./lib/python3.10/site-packages (from sympy->torch) (1.3.0)

# %%
# !pip3.10 install --upgrade jupyter ipywidgets
# !pip3.10 install --upgrade tqdm
# Out:
# Requirement already satisfied: jupyter in ./lib/python3.10/site-packages (1.0.0)
# Requirement already satisfied: ipywidgets in ./lib/python3.10/site-packages (8.1.2)
# Requirement already satisfied: ipykernel in ./lib/python3.10/site-packages (from jupyter) (6.29.4)
# Requirement already satisfied: nbconvert in ./lib/python3.10/site-packages (from jupyter) (7.16.4)
# Requirement already satisfied: qtconsole in ./lib/python3.10/site-packages (from jupyter) (5.5.2)
# Requirement already satisfied: notebook in ./lib/python3.10/site-packages (from jupyter) (7.1.3)
# Requirement already satisfied: jupyter-console in ./lib/python3.10/site-packages (from jupyter) (6.6.3)
# Requirement already satisfied: widgetsnbextension~=4.0.10 in ./lib/python3.10/site-packages (from ipywidgets) (4.0.10)
# Requirement already satisfied: ipython>=6.1.0 in ./lib/python3.10/site-packages (from ipywidgets) (8.24.0)
# Requirement already satisfied: traitlets>=4.3.1 in ./lib/python3.10/site-packages (from ipywidgets) (5.14.3)
# Requirement already satisfied: comm>=0.1.3 in ./lib/python3.10/site-packages (from ipywidgets) (0.2.2)
# Requirement already satisfied: jupyterlab-widgets~=3.0.10 in ./lib/python3.10/site-packages (from ipywidgets) (3.0.10)
# Requirement already satisfied: matplotlib-inline in ./lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in ./lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (4.9.0)
# Requirement already satisfied: jedi>=0.16 in ./lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.19.1)
# Requirement already satisfied: decorator in ./lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (5.1.1)
# Requirement already satisfied: typing-extensions>=4.6 in ./lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (4.11.0)
# Requirement already satisfied: pygments>=2.4.0 in ./lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (2.18.0)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in ./lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (3.0.43)
# Requirement already satisfied: stack-data in ./lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.6.3)
# Requirement already satisfied: exceptiongroup in ./lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (1.2.1)
# Requirement already satisfied: nest-asyncio in ./lib/python3.10/site-packages (from ipykernel->jupyter) (1.6.0)
# Requirement already satisfied: pyzmq>=24 in ./lib/python3.10/site-packages (from ipykernel->jupyter) (26.0.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in ./lib/python3.10/site-packages (from ipykernel->jupyter) (5.7.2)
# Requirement already satisfied: tornado>=6.1 in ./lib/python3.10/site-packages (from ipykernel->jupyter) (6.4)
# Requirement already satisfied: jupyter-client>=6.1.12 in ./lib/python3.10/site-packages (from ipykernel->jupyter) (8.6.1)
# Requirement already satisfied: psutil in ./lib/python3.10/site-packages (from ipykernel->jupyter) (5.9.8)
# Requirement already satisfied: debugpy>=1.6.5 in ./lib/python3.10/site-packages (from ipykernel->jupyter) (1.8.1)
# Requirement already satisfied: packaging in ./lib/python3.10/site-packages (from ipykernel->jupyter) (24.0)
# Requirement already satisfied: nbclient>=0.5.0 in ./lib/python3.10/site-packages (from nbconvert->jupyter) (0.10.0)
# Requirement already satisfied: markupsafe>=2.0 in ./lib/python3.10/site-packages (from nbconvert->jupyter) (2.1.5)
# Requirement already satisfied: tinycss2 in ./lib/python3.10/site-packages (from nbconvert->jupyter) (1.3.0)
# Requirement already satisfied: defusedxml in ./lib/python3.10/site-packages (from nbconvert->jupyter) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in ./lib/python3.10/site-packages (from nbconvert->jupyter) (0.3.0)
# Requirement already satisfied: nbformat>=5.7 in ./lib/python3.10/site-packages (from nbconvert->jupyter) (5.10.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in ./lib/python3.10/site-packages (from nbconvert->jupyter) (1.5.1)
# Requirement already satisfied: mistune<4,>=2.0.3 in ./lib/python3.10/site-packages (from nbconvert->jupyter) (3.0.2)
# Requirement already satisfied: bleach!=5.0.0 in ./lib/python3.10/site-packages (from nbconvert->jupyter) (6.1.0)
# Requirement already satisfied: jinja2>=3.0 in ./lib/python3.10/site-packages (from nbconvert->jupyter) (3.1.4)
# Requirement already satisfied: beautifulsoup4 in ./lib/python3.10/site-packages (from nbconvert->jupyter) (4.12.3)
# Requirement already satisfied: jupyterlab-server<3,>=2.22.1 in ./lib/python3.10/site-packages (from notebook->jupyter) (2.27.1)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in ./lib/python3.10/site-packages (from notebook->jupyter) (0.2.4)
# Requirement already satisfied: jupyterlab<4.2,>=4.1.1 in ./lib/python3.10/site-packages (from notebook->jupyter) (4.1.8)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in ./lib/python3.10/site-packages (from notebook->jupyter) (2.14.0)
# Requirement already satisfied: qtpy>=2.4.0 in ./lib/python3.10/site-packages (from qtconsole->jupyter) (2.4.1)
# Requirement already satisfied: six>=1.9.0 in ./lib/python3.10/site-packages (from bleach!=5.0.0->nbconvert->jupyter) (1.16.0)
# Requirement already satisfied: webencodings in ./lib/python3.10/site-packages (from bleach!=5.0.0->nbconvert->jupyter) (0.5.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in ./lib/python3.10/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./lib/python3.10/site-packages (from jupyter-client>=6.1.12->ipykernel->jupyter) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5 in ./lib/python3.10/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter) (4.2.1)
# Requirement already satisfied: overrides>=5.0 in ./lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter) (7.7.0)
# Requirement already satisfied: terminado>=0.8.3 in ./lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter) (0.18.1)
# Requirement already satisfied: argon2-cffi>=21.1 in ./lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter) (23.1.0)
# Requirement already satisfied: prometheus-client>=0.9 in ./lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter) (0.20.0)
# Requirement already satisfied: anyio>=3.1.0 in ./lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter) (4.3.0)
# Requirement already satisfied: websocket-client>=1.7 in ./lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter) (1.8.0)
# Requirement already satisfied: send2trash>=1.8.2 in ./lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter) (1.8.3)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in ./lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter) (0.5.3)
# Requirement already satisfied: jupyter-events>=0.9.0 in ./lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter) (0.10.0)
# Requirement already satisfied: tomli>=1.2.2 in ./lib/python3.10/site-packages (from jupyterlab<4.2,>=4.1.1->notebook->jupyter) (2.0.1)
# Requirement already satisfied: httpx>=0.25.0 in ./lib/python3.10/site-packages (from jupyterlab<4.2,>=4.1.1->notebook->jupyter) (0.27.0)
# Requirement already satisfied: async-lru>=1.0.0 in ./lib/python3.10/site-packages (from jupyterlab<4.2,>=4.1.1->notebook->jupyter) (2.0.4)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in ./lib/python3.10/site-packages (from jupyterlab<4.2,>=4.1.1->notebook->jupyter) (2.2.5)
# Requirement already satisfied: json5>=0.9.0 in ./lib/python3.10/site-packages (from jupyterlab-server<3,>=2.22.1->notebook->jupyter) (0.9.25)
# Requirement already satisfied: babel>=2.10 in ./lib/python3.10/site-packages (from jupyterlab-server<3,>=2.22.1->notebook->jupyter) (2.15.0)
# Requirement already satisfied: requests>=2.31 in ./lib/python3.10/site-packages (from jupyterlab-server<3,>=2.22.1->notebook->jupyter) (2.31.0)
# Requirement already satisfied: jsonschema>=4.18.0 in ./lib/python3.10/site-packages (from jupyterlab-server<3,>=2.22.1->notebook->jupyter) (4.22.0)
# Requirement already satisfied: fastjsonschema>=2.15 in ./lib/python3.10/site-packages (from nbformat>=5.7->nbconvert->jupyter) (2.19.1)
# Requirement already satisfied: ptyprocess>=0.5 in ./lib/python3.10/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets) (0.7.0)
# Requirement already satisfied: wcwidth in ./lib/python3.10/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.2.13)
# Requirement already satisfied: soupsieve>1.2 in ./lib/python3.10/site-packages (from beautifulsoup4->nbconvert->jupyter) (2.5)
# Requirement already satisfied: asttokens>=2.1.0 in ./lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.4.1)
# Requirement already satisfied: executing>=1.2.0 in ./lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.0.1)
# Requirement already satisfied: pure-eval in ./lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.2.2)
# Requirement already satisfied: sniffio>=1.1 in ./lib/python3.10/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (1.3.1)
# Requirement already satisfied: idna>=2.8 in ./lib/python3.10/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (3.7)
# Requirement already satisfied: argon2-cffi-bindings in ./lib/python3.10/site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook->jupyter) (21.2.0)
# Requirement already satisfied: httpcore==1.* in ./lib/python3.10/site-packages (from httpx>=0.25.0->jupyterlab<4.2,>=4.1.1->notebook->jupyter) (1.0.5)
# Requirement already satisfied: certifi in ./lib/python3.10/site-packages (from httpx>=0.25.0->jupyterlab<4.2,>=4.1.1->notebook->jupyter) (2024.2.2)
# Requirement already satisfied: h11<0.15,>=0.13 in ./lib/python3.10/site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab<4.2,>=4.1.1->notebook->jupyter) (0.14.0)
# Requirement already satisfied: referencing>=0.28.4 in ./lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook->jupyter) (0.35.1)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in ./lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook->jupyter) (2023.12.1)
# Requirement already satisfied: attrs>=22.2.0 in ./lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook->jupyter) (23.2.0)
# Requirement already satisfied: rpds-py>=0.7.1 in ./lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook->jupyter) (0.18.1)
# Requirement already satisfied: python-json-logger>=2.0.4 in ./lib/python3.10/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (2.0.7)
# Requirement already satisfied: pyyaml>=5.3 in ./lib/python3.10/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (6.0.1)
# Requirement already satisfied: rfc3339-validator in ./lib/python3.10/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in ./lib/python3.10/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (0.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./lib/python3.10/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.22.1->notebook->jupyter) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./lib/python3.10/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.22.1->notebook->jupyter) (2.2.1)
# Requirement already satisfied: webcolors>=1.11 in ./lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook->jupyter) (1.13)
# Requirement already satisfied: isoduration in ./lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook->jupyter) (20.11.0)
# Requirement already satisfied: fqdn in ./lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook->jupyter) (1.5.1)
# Requirement already satisfied: uri-template in ./lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook->jupyter) (1.3.0)
# Requirement already satisfied: jsonpointer>1.13 in ./lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook->jupyter) (2.4)
# Requirement already satisfied: cffi>=1.0.1 in ./lib/python3.10/site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook->jupyter) (1.16.0)
# Requirement already satisfied: pycparser in ./lib/python3.10/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook->jupyter) (2.22)
# Requirement already satisfied: arrow>=0.15.0 in ./lib/python3.10/site-packages (from isoduration->jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook->jupyter) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in ./lib/python3.10/site-packages (from arrow>=0.15.0->isoduration->jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook->jupyter) (2.9.0.20240316)
# Requirement already satisfied: tqdm in ./lib/python3.10/site-packages (4.66.4)

# %%
# Check cuda is installed
import torch
torch.cuda.is_available()
torch.cuda.device_count()
torch.cuda.current_device()
torch.cuda.get_device_name(0)
# Out:
# 'NVIDIA GeForce RTX 4060 Ti'

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from matplotlib import cm

import torch
from torchvision import datasets, transforms

def is_notebook():
    try:
        shell = get_ipython().__class__.__name__
        if shell == 'ZMQInteractiveShell':
            return True  # Jupyter notebook or qtconsole
        elif shell == 'TerminalInteractiveShell':
            return False  # Terminal running IPython
        else:
            return False  # Other type (?)
    except NameError:
        return False  # Probably standard Python interpreter

if is_notebook():
    # from tqdm import tqdm_notebook as tqdm
    from tqdm.notebook import tqdm
else:
    from tqdm import tqdm

# %%
# From https://jakevdp.github.io/PythonDataScienceHandbook/06.00-figure-code.html#Principal-Components-Rotation
def draw_vector(v0, v1, ax=None):
    ax = ax or plt.gca()
    arrowprops=dict(arrowstyle='->',
                    linewidth=2,
                    shrinkA=0, shrinkB=0)
    ax.annotate('', v1, v0, arrowprops=arrowprops)

def project_points(src, tgt, ax=None, color='red'):
    ax = ax or plt.gca()
    src2 = tgt * np.dot(src, tgt) / np.linalg.norm(tgt)
    ax.plot([src[0], src2[0]], [src[1], src2[1]], color=color, lw=.7)

def draw_projection(v0, v1, ax=None):
    ax = ax or plt.gca()
    arrowprops=dict(arrowstyle='->',
                    linewidth=.8,
                    shrinkA=0, shrinkB=0)
    ax.annotate('', v1, v0, arrowprops=arrowprops)

# %%
rng = np.random.RandomState(1)
X = np.dot(rng.rand(2, 2), rng.randn(2, 200)).T

fig, ax = plt.subplots(1, 1, figsize=(7, 6))

# plot data
ax.scatter(X[:, 0], X[:, 1], alpha=0.2)
ax.set_xlim(-2.5, 2.5)
ax.set_ylim(-2.5, 2.5)
ax.set(xlabel='x', ylabel='y', title='input')
plt.show()

# %%
pca = PCA(n_components=2, whiten=True)
pca.fit(X)

# plot data
fig, ax = plt.subplots(1, 1, figsize=(7, 6))
ax.scatter(X[:, 0], X[:, 1], alpha=0.2)
for length, vector in zip(pca.explained_variance_, pca.components_):
    v = vector * 3 * np.sqrt(length)
    draw_vector(pca.mean_, pca.mean_ + v, ax=ax)

ax.set_xlim(-2.5, 2.5)
ax.set_ylim(-2.5, 2.5)
ax.set(xlabel='x', ylabel='y', title='input and first 2 PCs');

# %% [markdown]
# ## Projections
#
# Projection is the location on a target vector to which another point/vector maps orthogonally.
#
# The figure below shows the projection of some of the points onto the first PC.

# %%
fig, ax = plt.subplots(1, 1, figsize=(14, 12))
ax.scatter(X[:, 0], X[:, 1], alpha=0.2)
for length, vector in zip(pca.explained_variance_, pca.components_):
    v = vector * 3 * np.sqrt(length)
    draw_vector(pca.mean_, pca.mean_ + v, ax=ax)

pts = X.copy()
pts = pts[np.argsort( pts[:, 0] ), :]
pts = pts[1::22]
for pt in pts:
    project_points(pt, pca.components_[0], ax, color='red')
    project_points(pt, pca.components_[1], ax, color='blue')

ax.set_xlim(-2.5, 2.5)
ax.set_ylim(-2.5, 2.5)
ax.set(xlabel='x', ylabel='y', title='input and first 2 PCs');

# %% [markdown]
# Since the PCs are orthogonal, we can call them axes and apply rotations so that they map onto Cartesian coordinates.
#
# Furthermore, we can normalize each vector to rescale the points along each axis.

# %%
fig, ax = plt.subplots(1, 2, figsize=(16, 8))
fig.subplots_adjust(left=0.0625, right=0.95, wspace=0.1)

# plot data
ax[0].scatter(X[:, 0], X[:, 1], alpha=0.2)
ax[0].scatter(X[1, 0], X[1, 1], alpha=0.8, color='red')
for length, vector in zip(pca.explained_variance_, pca.components_):
    v = vector * 3 * np.sqrt(length)
    draw_vector(pca.mean_, pca.mean_ + v, ax=ax[0])
# ax[0].axis('equal');
ax[0].set(xlabel='x', ylabel='y', title='input')
ax[0].set_xlim(-2.5, 2.5)
ax[0].set_ylim(-2.5, 2.5)
ax[0].set(xlabel='x', ylabel='y', title='input and first 2 PCs');

# plot principal components
X_pca = pca.transform(X)

ax[1].scatter(X_pca[:, 0], X_pca[:, 1], alpha=0.2)
ax[1].scatter(X_pca[1, 0], X_pca[1, 1], alpha=0.8, color='red')

draw_vector([0, 0], [0, 3], ax=ax[1])
draw_vector([0, 0], [3, 0], ax=ax[1])
# ax[1].axis('equal')
ax[1].set(xlabel='component 1', ylabel='component 2',
          title='principal components',
          xlim=(-5, 5), ylim=(-3, 3.1))
ax[1].set_xlim(-3.2, 3.2)
ax[1].set_ylim(-3.2, 3.2);

# %% [markdown]
# We can apply the inverse transform and see that we get the same points back.

# %%
Y = pca.inverse_transform(X_pca)
fig, ax = plt.subplots(1, 1, figsize=(14, 12))
ax.scatter(X[:, 0], X[:, 1], alpha=0.5)
ax.scatter(Y[:, 0], Y[:, 1], alpha=1., marker='x')
ax.set_xlim(-2.5, 2.5)
ax.set_ylim(-2.5, 2.5)
ax.set(xlabel='x', ylabel='y', title='input and conversion back');

# %% [markdown]
# * The length of the eigenvector is proportionally relevant to the variance explained.
#
# * Above, for visualization purposes, the square root of the eigenvalue (the magnitude of the eigenvector) was used.

# %%
print(f'The amount of variance explained by the first PC is {pca.explained_variance_[0]:.3f}')
print(f'The amount of variance explained by the second PC is {pca.explained_variance_[1]:.3f}')
print(f'Total amount of variance explained by the first two PCs is {np.sum(pca.explained_variance_):.3f}')
print(f'Proportional amount of variance explained: {pca.explained_variance_ratio_[0]:.3f}, {pca.explained_variance_ratio_[1]:.3f}')
# Out:
# The amount of variance explained by the first PC is 0.763
# The amount of variance explained by the second PC is 0.018
# Total amount of variance explained by the first two PCs is 0.781
# Proportional amount of variance explained: 0.976, 0.024

# %% [markdown]
# ##Correlation Matrix
#
# * The difference between the covariance matrix and the correlation matrix, is that the correlation matrix is normalized so that the min and max are [-1, 1]. -1, is perfectly anti-correlated and 1 is perfectly correlated. 0 has no correlation.
#
# * Given the data, X, where rows are the samples and the columns are the features, we can ask for the pairwise correlation between the columns and get a n_column by n_column correlation matrix:

# %%
cor_x = np.corrcoef(X.T)
print(f'Correlation Matrix:\n {cor_x}')
# Out:
# Correlation Matrix:
#  [[1.         0.88938995]
#  [0.88938995 1.        ]]

# %% [markdown]
# * The diagonal will be ones because rowcolumn[i] is perfectly correlated with itself.
#
# * The matrix should reflect about the diagonal because correlation does not consider direction, so really all we need is a triangular matrix.
#
# * The above shows that there is nearly 90% correlation between the first and second columns of the data.
#
# * Again, this was also supported by the first principal component explaining so much of the data -- if there is high correlation, the second component will not give us much of anything unique.

# %% [markdown]
# The eigenvectors and values of our correlation matrix are:

# %%
eig_vals, eig_vecs = np.linalg.eig(cor_x)
print('Eigenvectors \n%s' %eig_vecs)
print('\nEigenvalues \n%s' %eig_vals)
# Out:
# Eigenvectors
# [[-0.70710678 -0.70710678]
#  [ 0.70710678 -0.70710678]]
#
# Eigenvalues
# [0.11061005 1.88938995]

# %% [markdown]
# # PCA with Fashion MNIST

# %% [markdown]
# We will now consider PCA with MNIST images. We will use Pytorch simply for the data loading.

# %%
batch_size = 28

train_dataset = datasets.FashionMNIST('./fashion_mnist',
                               train=True,
                               download=True,
                               transform=transforms.Compose([
                       transforms.ToTensor(),
#                       transforms.Normalize((0.1307,), (0.3081,))
                   ]))

test_dataset = datasets.FashionMNIST('./fashion_mnist',
                                    train=False,
                               transform=transforms.Compose([
                       transforms.ToTensor(),
#                       transforms.Normalize((0.1307,), (0.3081,))
                   ]))

train_loader = torch.utils.data.DataLoader(dataset=train_dataset,
                                           batch_size=batch_size,
                                           shuffle=True)

test_loader = torch.utils.data.DataLoader(dataset=test_dataset,
                                                batch_size=batch_size,
                                                shuffle=False)

images = train_loader.dataset.data.detach().numpy().reshape(-1, 28*28)
print(f'Num training images: {len(images)},\tmin val: {images.min():.3f},\tmax val: {images.max():.3f}')
# Out:
# Num training images: 60000,	min val: 0.000,	max val: 255.000

# %%
# pltsize=1
# plt.figure(figsize=(10*pltsize, pltsize*1.1))

# for i in range(10):
#     plt.subplot(1,10,i+1)
#     plt.axis('off')
#     plt.imshow(train_loader.dataset.data[i].numpy().reshape(28,28), cmap="gray_r")
#     plt.title(str(train_loader.dataset.targets[i].item()))

import random
pltsize = 1
plt.figure(figsize=(10*pltsize, pltsize*1.1))
random_indices = random.sample(range(len(train_loader.dataset)), 10)
for i, idx in enumerate(random_indices):
    plt.subplot(1, 10, i+1)
    plt.axis('off')
    plt.imshow(train_loader.dataset.data[idx].numpy().reshape(28,28), cmap="gray_r")
    plt.title(str(train_loader.dataset.targets[idx].item()))

# %%
# %%time
c = np.nan_to_num(np.corrcoef(images.T))  # Normalized [-1, 1] covariance matrix
# c = np.cov(images.T)
# Out:
# CPU times: user 1.76 s, sys: 1.15 s, total: 2.91 s
# Wall time: 358 ms

# %%
c.shape, c.min(), c.max()
# Out:
# ((784, 784), -0.6577623419657905, 1.0)

# %%
fig = plt.figure()
plt.imshow(c.sum(axis=0).reshape(28,28), interpolation='nearest')
plt.title('Sum of cross-correlation matrix');

# %%
side_dim = 28
data = c.reshape(side_dim, side_dim, side_dim, side_dim)
fig = plt.figure(figsize=(8,8))
ax = fig.add_axes([.1, .1, .8, .8])
implot = ax.imshow(data[side_dim>>1, side_dim>>1].reshape(side_dim, side_dim),
                   interpolation='nearest', clim=(-1,1))
text=ax.text(-.5,-1, "", va="bottom", ha="left")

last_x, last_y = -1, -1

def onmotion(event):
    global last_x
    global last_y
    global data
    global side_dim
    global text
    global implot
    x = int(np.rint(event.xdata))
    y = int(np.rint(event.ydata))
    if last_x != x or last_y != y and x >=0 and y >= 0:
#         plt.cla()  # Try and see if this keeps it from bogging down with more and more interactivity.
        implot.set_array(data[y, x].reshape(side_dim, side_dim))
        last_x = x
        last_y = y
#     tx = 'x=%d, y=%d, xdata=%f, ydata=%f, x=%d, y=%d' % \
#     (event.x, event.y, event.xdata, event.ydata, x, y)
#     text.set_text(tx)

cid = implot.figure.canvas.mpl_connect('motion_notify_event', onmotion)

# %% [markdown]
# ## First PCs of Fashion
#
# Let's look at the first principal components as derived from PCA:

# %%
# %%time
n_components = 10
pca = PCA(n_components=n_components)
pca.fit(images)
fig = plt.figure(figsize=(n_components*np.power(n_components, 1/5),3))
axes = []
for i in range(n_components):
    ax_ = fig.add_subplot(1, n_components, i+1)
    ax_.imshow(pca.components_[i].reshape(28,28), interpolation='nearest', clim=(-.15, .15));
    ax_.set_title(f'PC {i+1}')
    ax_.axis('off')

    axes.append(ax_)
# Out:
# CPU times: user 13.1 s, sys: 3.74 s, total: 16.9 s
# Wall time: 1.67 s

# %%
# %%time
n_components = 10
pca = PCA(n_components=233)
pca.fit(images)
fig = plt.figure(figsize=(n_components*np.power(n_components, 1/5),3))
axes = []
for i in range(n_components+1, 1, -1):
    ax_ = fig.add_subplot(1, n_components, i-1)
    ax_.imshow(pca.components_[-i].reshape(28,28), interpolation='nearest', clim=(-.15, .15));
    ax_.set_title(f'PC {-i-1}')
    ax_.axis('off')
    axes.append(ax_)
# Out:
# CPU times: user 51.1 s, sys: 11.1 s, total: 1min 2s
# Wall time: 5.51 s

# %%
fig = plt.figure(figsize=(3, 3))
ax = fig.add_subplot(111)
ax.matshow(images.mean(axis=0).reshape(28, 28), cmap = cm.binary)
# ax.plot(pca.mean_)
plt.xticks(np.array([]))
plt.yticks(np.array([]))
plt.title('Average pixel weights')
plt.show()
print("Max of mean:", images.mean(axis=0).max())
# Out:
# Max of mean: 161.87638333333334

# %% [markdown]
# ## Effect of iterative PCs
#
# Consider the impact of applying PCs.

# %%
# We will apply a Fibonacci sequence for illustrative purposes.
def fib(n):
    a, b = 1, 2  # Normally we'd start at 0, 1, but we don't want that...
    for _ in range(n):
        yield a
        a, b = b, a + b

# %%
# Try PCA on first ten test images
n_images = 8
n_components = 12
test_images = np.array(test_loader.dataset.data[:n_images].numpy().reshape((n_images,784)))
# Plot the first ten test images and the corresponding outputs
fig = plt.figure(figsize=(10, n_components))
ax = fig.add_subplot(111)
images_in = [test_images[j].reshape(-1, 28) for j in range(n_images)]
image = np.concatenate(images_in, axis=1)

for i in tqdm(fib(n_components), total=n_components):
    pca = PCA(n_components=i)
    pca.fit(images)
    test_outputs = pca.inverse_transform(pca.transform(test_images))
    images_out = [test_outputs[j].reshape(-1, 28) for j in range(n_images)]
    image_out = np.concatenate(images_out, axis=1)
    image = np.concatenate([image, image_out])
ax.matshow(image, cmap = cm.binary)
ax.set_xticks(np.array([]))
y_lim = ax.get_ylim()
y_scale = (y_lim[0] - y_lim[1])/(n_components+1)
ax.set_yticks(np.linspace(.5, n_components+.5, n_components+1) * y_scale)
a = [0]
a.extend(list(fib(n_components)))
ax.set_yticklabels(a)
plt.show()
# Out:
#   0%|          | 0/12 [00:00<?, ?it/s]

# %% [markdown]
# ## Closer inspection.
#
# Consider the application of the first PC to the first image.

# %%
def draw_apply_PC0(idx):
    fig = plt.figure(figsize=(5,3))
    pca0_applied = pca.components_[0].reshape(28, 28) * pca.transform(test_images)[idx][0]
    image = pca.mean_.reshape(28, 28) + pca0_applied

    absmin = np.min([test_images[idx].min(), pca.mean_.min(), pca0_applied.min(), image.min()])
    absmax = np.max([test_images[idx].max(), pca.mean_.max(), pca0_applied.max(), image.max()])

    ax_ = fig.add_subplot(1, 4, 1)
    ax_.imshow(test_images[idx].reshape(28,28), interpolation='nearest', clim=(absmin, absmax), cmap = cm.binary);
    ax_.set_title(f'original')
    ax_.axis('off')

    ax_ = fig.add_subplot(1, 4, 2)
    ax_.imshow(pca.mean_.reshape(28,28), interpolation='nearest', clim=(absmin, absmax), cmap = cm.binary);
    ax_.set_title(f'mean')
    ax_.axis('off')

    ax_ = fig.add_subplot(1, 4, 3)
    ax_.imshow(pca0_applied, interpolation='nearest', clim=(absmin, absmax), cmap = cm.binary);
    ax_.set_title(f'PC 1')
    ax_.axis('off')

    ax_ = fig.add_subplot(1, 4, 4)
    ax_.imshow(image, interpolation='nearest', clim=(absmin, absmax), cmap = cm.binary);
    ax_.set_title(f'Applied')
    ax_.axis('off')

    print(f'PC_0 min: {pca.components_[0].min():.4f},\tPC_0 max: {pca.components_[0].max():.4f}')
    print(f'mean_img min: {pca.mean_.min():.4f},\tmean_img max: {pca.mean_.max():.4f}')
    print(f'Ammount to apply: {pca.transform(test_images)[idx][0]:.4f}')

    fig = plt.figure(figsize=(8, 4))
    ax = fig.add_subplot(111)
    ax.plot(pca.transform(test_images[idx].reshape(1, -1)).flatten())
    ax.axhline(0, lw=.5, color='k') # horizontal lines

    ax.set_title('Amount of each PC applied.')

# %%
import random
for i in range(5):
    number = random.randint(0, 8)
    print(number)
    draw_apply_PC0(number)
# Out:
# 2
# PC_0 min: -0.0364,	PC_0 max: 0.0653
# mean_img min: 0.0008,	mean_img max: 161.8764
# Ammount to apply: 385.4747
# 3
# PC_0 min: -0.0364,	PC_0 max: 0.0653
# mean_img min: 0.0008,	mean_img max: 161.8764
# Ammount to apply: -344.0138
# 5
# PC_0 min: -0.0364,	PC_0 max: 0.0653
# mean_img min: 0.0008,	mean_img max: 161.8764
# Ammount to apply: 289.7983
# 3
# PC_0 min: -0.0364,	PC_0 max: 0.0653
# mean_img min: 0.0008,	mean_img max: 161.8764
# Ammount to apply: -344.0138
# 5
# PC_0 min: -0.0364,	PC_0 max: 0.0653
# mean_img min: 0.0008,	mean_img max: 161.8764
# Ammount to apply: 289.7983
